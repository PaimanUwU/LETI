# %% [markdown]
# Crimes by District OPENDOSM prediction using Poisson Regression & Random Forest Regressor

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("crime_district.csv")

df.head()
# Out:
#       state district category type        date  crimes
# 0  Malaysia      All  assault  all  2016-01-01   22327
# 1  Malaysia      All  assault  all  2017-01-01   21366
# 2  Malaysia      All  assault  all  2018-01-01   16902
# 3  Malaysia      All  assault  all  2019-01-01   16489
# 4  Malaysia      All  assault  all  2020-01-01   13279

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 19152 entries, 0 to 19151
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   state     19152 non-null  str
#  1   district  19152 non-null  str
#  2   category  19152 non-null  str
#  3   type      19152 non-null  str
#  4   date      19152 non-null  str
#  5   crimes    19152 non-null  int64
# dtypes: int64(1), str(5)
# memory usage: 897.9 KB

# %%
df.describe()
# Out:
#              crimes
# count  19152.000000
# mean     189.728018
# std     1590.813293
# min        0.000000
# 25%        1.000000
# 50%       12.000000
# 75%       66.000000
# max    90028.000000

# %%
df.columns
# Out:
# Index(['state', 'district', 'category', 'type', 'date', 'crimes'], dtype='str')

# %%
df['state'].unique()
# Out:
# <StringArray>
# [         'Malaysia',             'Johor',             'Kedah',
#           'Kelantan',            'Melaka',   'Negeri Sembilan',
#             'Pahang',             'Perak',            'Perlis',
#       'Pulau Pinang',             'Sabah',           'Sarawak',
#           'Selangor',        'Terengganu', 'W.P. Kuala Lumpur']
# Length: 15, dtype: str

# %%
df['district'].unique()
# Out:
# <StringArray>
# [                'All',          'Batu Pahat',     'Iskandar Puteri',
#  'Johor Bahru Selatan',   'Johor Bahru Utara',              'Kluang',
#          'Kota Tinggi',           'Kulaijaya',              'Ledang',
#              'Mersing',
#  ...
#              'Kemaman',    'Kuala Terengganu',              'Marang',
#                'Setiu',         'Brickfields',              'Cheras',
#           'Dang Wangi',              'Sentul',      'W.P. Putrajaya',
#          'Wangsa Maju']
# Length: 160, dtype: str

# %%
state_crime = df.groupby('state')['crimes'].sum().sort_values(ascending=False)

state_crime.plot(kind='bar')
plt.title("Total Crimes by State")
plt.show()
